# %% [markdown]
# #### This notebook is used to conduct parameters estimation under the Stochastic Block Model (SBM) setting.

# %%
# Importing utils functions needed for simulation studies
import utils
from importlib import reload
reload(utils)
# Out:
# <module 'utils' from '/mnt/code/simulation/scripts/utils.py'>

# %%
# Importing necessary packages
import pandas as pd
import sys,codecs
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import scipy.stats as st
import collections
import statsmodels.api as sm
from time import time
import random

# %%
# Importing Ray, a distributed computing framework for enabling parallel and scalable execution
import ray

ray.init(address='auto')
# Out:
# 2025-07-27 15:34:30,159	INFO worker.py:1747 -- Connecting to existing Ray cluster at address: 192.168.1.7:6379...
# 2025-07-27 15:34:30,218	INFO worker.py:1927 -- Connected to Ray cluster.
# RayContext(dashboard_url='', python_version='3.12.4', ray_version='2.48.0', ray_commit='03491225d59a1ffde99c3628969ccf456be13efd')
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 4.636100950961921 Z_err_max1: 4.4003303832439125
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 4.3888966413125825 Z_err_max1: 5.58307786260088
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 4.924954618858843 Z_err_max1: 4.769929875188988
# (map_fun_fmle pid=15152) cmle is over [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (map_fun_fmle pid=15152) Z_err_max: 4.98383818703004 Z_err_max1: 4.951154974059493 [repeated 3x across cluster]
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15151) cmle is over [repeated 9x across cluster]
# (map_fun_fmle pid=15151) Z_err_max: 6.232976494086492 Z_err_max1: 4.688129281700563 [repeated 9x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over [repeated 11x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 5.106499247300402 Z_err_max1: 3.6439162540326127 [repeated 11x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) cmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=17875, ip=192.168.1.6) Z_err_max: 6.073354196522365 Z_err_max1: 4.618388859748464 [repeated 5x across cluster]
# (map_fun_fmle pid=15144) SARX is over [repeated 6x across cluster]
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15146) SARX is over [repeated 9x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) SARX is over [repeated 10x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=17875, ip=192.168.1.6) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over [repeated 12x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 5.202724687625426 Z_err_max1: 5.28135516107146
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over [repeated 10x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 7.151529362627418 Z_err_max1: 4.625485231865053
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 6.067806926463905 Z_err_max1: 5.101261637571618
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 6.0882941713895296 Z_err_max1: 3.4225306134797027
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 6.271479806017512 Z_err_max1: 4.332768752894109
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15151) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=15144) Z_err_max: 4.544409524848515 Z_err_max1: 3.981665754921435 [repeated 2x across cluster]
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15148) cmle is over
# (map_fun_fmle pid=15144) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15148) Z_err_max: 6.442900056387518 Z_err_max1: 3.8668787217333884
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 4.812902071601695 Z_err_max1: 4.5102445842194925 [repeated 2x across cluster]
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15146) cmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=15146) Z_err_max: 7.742613384322366 Z_err_max1: 4.077958906574988 [repeated 6x across cluster]
# (map_fun_fmle pid=15148) SARX is over
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.778251873047384 Z_err_max1: 4.623098457472892
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=15146) SARX is over [repeated 6x across cluster]
# (map_fun_fmle pid=17878, ip=192.168.1.6) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 5.853432161508993 Z_err_max1: 3.9964660430698027
# (map_fun_fmle pid=15146) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 5.739078569072493 Z_err_max1: 4.640433344451994
# (map_fun_fmle pid=15152) fmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15371, ip=192.168.1.8) Z_err_max: 5.523771328529147 Z_err_max1: 4.48241773659719 [repeated 3x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 5.522242404580207 Z_err_max1: 4.482200358764729
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 5.919462224949498 Z_err_max1: 3.833629729678008
# (map_fun_fmle pid=15371, ip=192.168.1.8) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 6.30076040431152 Z_err_max1: 3.7020875234594106
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 4.991370455094568 Z_err_max1: 4.288412414129951
# (map_fun_fmle pid=15376, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 6.7099774648997395 Z_err_max1: 4.577768678355313
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 6.1651340149595715 Z_err_max1: 4.406070605854591
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 4.819094662500041 Z_err_max1: 7.723291364935141
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 6.229577198059373 Z_err_max1: 3.463915915789643
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 5.270744845234198 Z_err_max1: 5.039450138458353
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=15150) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15150) Z_err_max: 5.90937045817545 Z_err_max1: 4.287742702146597 [repeated 2x across cluster]
# (map_fun_fmle pid=15150) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15148) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15148) Z_err_max: 5.924477080732959 Z_err_max1: 4.892510678165303 [repeated 2x across cluster]
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 5.413688674620509 Z_err_max1: 5.589112219986819
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15150) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15148) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) Z_err_max: 5.821669475989779 Z_err_max1: 3.980750216065916
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.599888532561893 Z_err_max1: 4.892021124424519 [repeated 5x across cluster]
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15146) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15146) Z_err_max: 5.820062995692895 Z_err_max1: 3.4326412383479132 [repeated 2x across cluster]
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15146) SARX is over [repeated 7x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.807418498434439 Z_err_max1: 4.307725124868437
# (map_fun_fmle pid=15146) fmle is over [repeated 7x across cluster]
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 6.060777392532728 Z_err_max1: 3.222404361032396
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 4.951473324213186 Z_err_max1: 4.959321058007263
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 5.416893747051361 Z_err_max1: 6.249284189769323
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) cmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 7.521646582813563 Z_err_max1: 3.2077023576190626 [repeated 6x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) SARX is over [repeated 5x across cluster]
# (map_fun_fmle pid=15152) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15376, ip=192.168.1.8) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 5.70411208784226 Z_err_max1: 5.126043079808413
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 5.826529544206008 Z_err_max1: 5.033695326330934
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 5.890982403470587 Z_err_max1: 4.06508565908272
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 5.173414816058938 Z_err_max1: 3.284582203945347
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 6.340769017552056 Z_err_max1: 3.8166694148927984
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 5.442330553384546 Z_err_max1: 4.087992045901226
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=15151) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15151) Z_err_max: 5.510796762557716 Z_err_max1: 4.347858723304752 [repeated 2x across cluster]
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=15151) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17331, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) Z_err_max: 6.601459696811694 Z_err_max1: 3.894870583792432
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 4.5801852024901555 Z_err_max1: 4.081762868915236 [repeated 2x across cluster]
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17331, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=15146) Z_err_max: 6.149867491935 Z_err_max1: 4.403319950893854
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) cmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=17875, ip=192.168.1.6) Z_err_max: 4.801275541660506 Z_err_max1: 4.226461949079833 [repeated 6x across cluster]
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.556181831116485 Z_err_max1: 4.041749105721106
# (map_fun_fmle pid=17875, ip=192.168.1.6) SARX is over [repeated 6x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over [repeated 7x across cluster]
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.03840329399446 Z_err_max1: 4.4519313387791755
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 5.467372753148877 Z_err_max1: 4.165467441854159
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 6.202205576292798 Z_err_max1: 5.739053892137191 [repeated 2x across cluster]
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 6.009496704712591 Z_err_max1: 3.485297071018029 [repeated 3x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15152) fmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15371, ip=192.168.1.8) Z_err_max: 4.850942788501838 Z_err_max1: 5.317253974428583 [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15371, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 5.175065494675693 Z_err_max1: 4.111595729127123
# (map_fun_fmle pid=15371, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 5.485546257357485 Z_err_max1: 3.7468081486125033
# (map_fun_fmle pid=17317, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) Z_err_max: 5.193689093985881 Z_err_max1: 4.174275479765326
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 6.691058314045799 Z_err_max1: 4.467983667244198
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 7.0995210805343225 Z_err_max1: 2.925298064687567
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 4.699329524176539 Z_err_max1: 4.499809395809022
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 6.363845576017139 Z_err_max1: 4.831847067920975
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=15148) cmle is over
# (map_fun_fmle pid=15148) Z_err_max: 6.061029877100458 Z_err_max1: 3.270040382608181
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 4.770279202371447 Z_err_max1: 3.77888464842911
# (map_fun_fmle pid=15148) SARX is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 7.124610169715272 Z_err_max1: 3.4524633810949457
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 5.810141627795501 Z_err_max1: 5.766437993318515
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 8.481709610705064 Z_err_max1: 4.509038004040559
# (map_fun_fmle pid=17875, ip=192.168.1.6) cmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=17875, ip=192.168.1.6) Z_err_max: 4.4916946520645356 Z_err_max1: 4.77020140971711 [repeated 5x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.698900067206466 Z_err_max1: 4.381036720975294
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=15146) Z_err_max: 7.16294900572634 Z_err_max1: 4.702880041930501
# (map_fun_fmle pid=17875, ip=192.168.1.6) SARX is over [repeated 5x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15146) SARX is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 5.7822622260256376 Z_err_max1: 5.511950861575782
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15146) fmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) Z_err_max: 7.395317285759651 Z_err_max1: 2.997766279898987
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.11379591756365 Z_err_max1: 3.451254794313831
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) Z_err_max: 6.270636353624695 Z_err_max1: 3.678692077850833
# (map_fun_fmle pid=17331, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 7.2268457425662875 Z_err_max1: 3.91559004981962
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 7.65644705531756 Z_err_max1: 4.416080219080054
# (map_fun_fmle pid=15370, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) cmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 5.595596581522497 Z_err_max1: 5.515601007596597 [repeated 4x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 8.44982515370284 Z_err_max1: 4.056512599252571 [repeated 2x across cluster]
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over [repeated 6x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 7.096029794597612 Z_err_max1: 3.866900152789972
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 5.617766830026209 Z_err_max1: 4.308913070972224
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 6.514609324649495 Z_err_max1: 3.8470059557326572
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 5.829493857718411 Z_err_max1: 3.8030499424460715
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=15148) cmle is over
# (map_fun_fmle pid=15148) Z_err_max: 7.326504058800957 Z_err_max1: 3.551106551860376
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=15148) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) Z_err_max: 5.794428043273994 Z_err_max1: 3.4346893737139688
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 7.161545917344777 Z_err_max1: 2.2086694958063533
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 8.451632309690034 Z_err_max1: 5.406497115040367
# (map_fun_fmle pid=17317, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 6.95746928969397 Z_err_max1: 2.8276072800400236
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 6.844845515092535 Z_err_max1: 4.03781455175127
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15146) Z_err_max: 5.532881256612788 Z_err_max1: 4.130298393895491
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 5.3448195407647505 Z_err_max1: 4.0325648313802 [repeated 3x across cluster]
# (map_fun_fmle pid=15146) SARX is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) cmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17880, ip=192.168.1.6) Z_err_max: 5.949723190929623 Z_err_max1: 4.026311233033875 [repeated 4x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over [repeated 4x across cluster]
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 5.46552884750166 Z_err_max1: 4.8905550015113555
# (map_fun_fmle pid=17879, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=17877, ip=192.168.1.6) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.0567483279278225 Z_err_max1: 4.095720038526988
# (map_fun_fmle pid=17880, ip=192.168.1.6) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 5.745199612506381 Z_err_max1: 5.755085957684586
# (map_fun_fmle pid=15370, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) Z_err_max: 5.152262377120797 Z_err_max1: 4.297719884344382
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 5.599488105138847 Z_err_max1: 3.737253210788488
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 8.898742868447547 Z_err_max1: 5.3157110230413345 [repeated 2x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) Z_err_max: 4.9586539125248095 Z_err_max1: 4.907886433963737
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 6.38728864849917 Z_err_max1: 3.7882107136263024
# (map_fun_fmle pid=15376, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 7.113075138257052 Z_err_max1: 4.005280550328773
# (map_fun_fmle pid=15371, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 5.818339424024076 Z_err_max1: 4.3165340390739715
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 5.504095088709372 Z_err_max1: 4.165777451617881
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 6.366793205018215 Z_err_max1: 5.0361616780482095
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) Z_err_max: 5.15492029468822 Z_err_max1: 4.888807880843783
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 4.5662092313116425 Z_err_max1: 4.74812506596947
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 4.629593676995985 Z_err_max1: 4.498791973122234
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=15145) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 5.82165440870195 Z_err_max1: 5.519951383134094
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15148) cmle is over
# (map_fun_fmle pid=15148) Z_err_max: 6.341417787452286 Z_err_max1: 3.790073307099194
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15148) SARX is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 5.307209632083862 Z_err_max1: 4.09469716668349
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 8.113315050728954 Z_err_max1: 3.8737813268083947
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) Z_err_max: 6.307331246262867 Z_err_max1: 3.5342948879890614
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) Z_err_max: 5.861449496622356 Z_err_max1: 4.077052861890804
# (map_fun_fmle pid=17877, ip=192.168.1.6) cmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17877, ip=192.168.1.6) Z_err_max: 4.5666723750294915 Z_err_max1: 3.8259446350190913 [repeated 4x across cluster]
# (map_fun_fmle pid=17879, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 6.718684682379809 Z_err_max1: 4.630459787377584 [repeated 4x across cluster]
# (map_fun_fmle pid=17877, ip=192.168.1.6) SARX is over [repeated 4x across cluster]
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.209332054801955 Z_err_max1: 4.266102110575779
# (map_fun_fmle pid=17878, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 5.2758320397265575 Z_err_max1: 3.6642085103822133
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over [repeated 4x across cluster]
# (map_fun_fmle pid=17877, ip=192.168.1.6) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.038520025704165 Z_err_max1: 4.453973024401831
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 6.464396480087753 Z_err_max1: 6.264478048606766
# (map_fun_fmle pid=15376, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 6.028860074683845 Z_err_max1: 5.323228398550772 [repeated 2x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) Z_err_max: 6.230465295210162 Z_err_max1: 4.373054956169401
# (map_fun_fmle pid=15376, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 5.242489546754719 Z_err_max1: 5.362112536748791
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 5.43137658831085 Z_err_max1: 5.258737278747151 [repeated 2x across cluster]
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 5.174563694009042 Z_err_max1: 5.809413347265943
# (map_fun_fmle pid=15376, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 5.507121172089694 Z_err_max1: 5.042441499086769
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15152) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15152) Z_err_max: 5.929251721732489 Z_err_max1: 4.052055253115192 [repeated 2x across cluster]
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 7.501048610852081 Z_err_max1: 3.624655608279591 [repeated 2x across cluster]
# (map_fun_fmle pid=15152) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=15148) SARX is over
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15152) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 4.999121173037389 Z_err_max1: 4.991483056736925
# (map_fun_fmle pid=17330, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 6.261715032990023 Z_err_max1: 5.109956924867866
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) Z_err_max: 5.145611923820848 Z_err_max1: 5.019521564428818
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 6.2276922424153796 Z_err_max1: 2.9136628609317334
# (map_fun_fmle pid=17331, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 6.640353435408669 Z_err_max1: 3.347051988266097
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 6.012498578983838 Z_err_max1: 3.136542944961641
# (map_fun_fmle pid=17877, ip=192.168.1.6) cmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=17877, ip=192.168.1.6) Z_err_max: 5.681354933094422 Z_err_max1: 5.488265119079316 [repeated 6x across cluster]
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) Z_err_max: 5.737345688795543 Z_err_max1: 3.805390061002852
# (map_fun_fmle pid=17877, ip=192.168.1.6) SARX is over [repeated 6x across cluster]
# (map_fun_fmle pid=17878, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) fmle is over [repeated 6x across cluster]
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 5.634346759663397 Z_err_max1: 5.184241789611962
# (map_fun_fmle pid=17880, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) Z_err_max: 4.345785963238841 Z_err_max1: 5.391993338581763
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 4.957170348096698 Z_err_max1: 5.513269132207295
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 6.486075285820915 Z_err_max1: 5.285837847009724 [repeated 3x across cluster]
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 6.156680673374796 Z_err_max1: 4.659417195504624 [repeated 2x across cluster]
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 9.573366773542835 Z_err_max1: 4.669033279819336
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 5.565079800062506 Z_err_max1: 4.7245958877755605
# (map_fun_fmle pid=15377, ip=192.168.1.8) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 8.60841512291365 Z_err_max1: 3.420693884736778 [repeated 2x across cluster]
# (map_fun_fmle pid=15377, ip=192.168.1.8) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 6.36929433854086 Z_err_max1: 4.929569747346978 [repeated 3x across cluster]
# (map_fun_fmle pid=15371, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 5.439792586274958 Z_err_max1: 4.622218092638658
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 5.940140716218872 Z_err_max1: 3.541339664317894
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=15148) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=15152) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 6.581193584455445 Z_err_max1: 3.0890410240938007
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 6.244980506958322 Z_err_max1: 3.730636483946591
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 5.5427589772356285 Z_err_max1: 3.6120320560698738
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 5.242745005491445 Z_err_max1: 4.982513273600215
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 7.188801033456162 Z_err_max1: 4.230685244768536
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=15146) Z_err_max: 6.7278343401870355 Z_err_max1: 5.3043667310726015
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) Z_err_max: 6.441111680324782 Z_err_max1: 5.557855659459504
# (map_fun_fmle pid=15146) SARX is over
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 5.8867928524312525 Z_err_max1: 4.118777874669149 [repeated 5x across cluster]
# (map_fun_fmle pid=15146) fmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) SARX is over [repeated 5x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 5.088262706453481 Z_err_max1: 3.8658305299390996 [repeated 2x across cluster]
# (map_fun_fmle pid=17879, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) fmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.9645481178947275 Z_err_max1: 3.237684536263515
# (map_fun_fmle pid=17880, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 5.807605968404216 Z_err_max1: 5.174623864442427
# (map_fun_fmle pid=15370, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) Z_err_max: 6.651838839789435 Z_err_max1: 4.076269108993544
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 4.671008078868605 Z_err_max1: 5.077314082660135
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=15148) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15148) Z_err_max: 7.235626524439594 Z_err_max1: 3.6905550419826247 [repeated 3x across cluster]
# (map_fun_fmle pid=15370, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 5.1229886518258425 Z_err_max1: 4.382390603803337
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 5.272144953812113 Z_err_max1: 3.9614408005802204
# (map_fun_fmle pid=15376, ip=192.168.1.8) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 6.117586500180221 Z_err_max1: 5.1546037831802405 [repeated 3x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 6.585639700013182 Z_err_max1: 3.2053265792330654
# (map_fun_fmle pid=15376, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 4.710816826409471 Z_err_max1: 3.7110114737120616
# (map_fun_fmle pid=15371, ip=192.168.1.8) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15145) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 7.093179708134699 Z_err_max1: 4.344995572323082
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 6.272391956423859 Z_err_max1: 5.841331263520603
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 6.91570662606938 Z_err_max1: 4.716032556522715 [repeated 2x across cluster]
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 6.445115174064885 Z_err_max1: 5.605614376995073
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 8.178187370197785 Z_err_max1: 5.353574068107619
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 5.134958734071874 Z_err_max1: 4.086855933730377
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=15146) Z_err_max: 5.939628833970053 Z_err_max1: 4.25797586274045
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=15146) SARX is over
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=15146) fmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) Z_err_max: 5.426664928973785 Z_err_max1: 3.9666207608509243
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 5.2269376092350495 Z_err_max1: 4.604372653017144 [repeated 4x across cluster]
# (map_fun_fmle pid=17879, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) Z_err_max: 7.4830975175073275 Z_err_max1: 5.197590459589346
# (map_fun_fmle pid=17881, ip=192.168.1.6) SARX is over [repeated 4x across cluster]
# (map_fun_fmle pid=17880, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) Z_err_max: 6.2313672930342054 Z_err_max1: 3.2150823642355304
# (map_fun_fmle pid=17875, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) fmle is over [repeated 5x across cluster]
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.199951122489226 Z_err_max1: 4.2295005336187295
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 6.896261453759065 Z_err_max1: 3.2045721661592443
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# ...
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 5.504336649204922 Z_err_max1: 3.40153194355286
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=17320, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) Z_err_max: 5.364401210528066 Z_err_max1: 5.236791466753382
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 6.833604963117787 Z_err_max1: 3.8111195264186897
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 5.6251599943410895 Z_err_max1: 5.4281546703053785
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 6.379763538829758 Z_err_max1: 3.9672878905266034
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=15145) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 5.926708492542311 Z_err_max1: 4.644816263531805
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 4.9575613231800695 Z_err_max1: 5.118269730740008
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 7.7100992455258925 Z_err_max1: 4.396438055587727
# (map_fun_fmle pid=15377, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=15147) SARX is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 5.231909660758525 Z_err_max1: 5.180205070667034
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 6.266831461811387 Z_err_max1: 3.718859392687732
# (map_fun_fmle pid=15377, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 6.806167727622146 Z_err_max1: 4.0153227724896485 [repeated 2x across cluster]
# (map_fun_fmle pid=15147) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 4.596017046956041 Z_err_max1: 4.6022256906488455
# (map_fun_fmle pid=15370, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 6.000368436419765 Z_err_max1: 4.198112852408209
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 5.637200208027882 Z_err_max1: 4.66951949309507
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 6.214813317081988 Z_err_max1: 5.047361860402569
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) Z_err_max: 5.76116425498337 Z_err_max1: 4.034471543500841
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=15146) Z_err_max: 6.867229968764866 Z_err_max1: 4.639674950485236
# (map_fun_fmle pid=15371, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15146) SARX is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 5.981069458988799 Z_err_max1: 2.739486484719752
# (map_fun_fmle pid=15146) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 6.49529377373505 Z_err_max1: 5.022519230811725
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) Z_err_max: 4.910683959482476 Z_err_max1: 5.445881374103131
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17875, ip=192.168.1.6) Z_err_max: 5.277569199060396 Z_err_max1: 4.930454894761891 [repeated 2x across cluster]
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 6.5215969290489815 Z_err_max1: 3.6719562007411577
# (map_fun_fmle pid=17878, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) Z_err_max: 5.41112503417856 Z_err_max1: 5.143927225771227
# (map_fun_fmle pid=17875, ip=192.168.1.6) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17877, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 5.945155990779993 Z_err_max1: 4.273788626914739
# (map_fun_fmle pid=17330, ip=192.168.1.5) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 6.387046106109469 Z_err_max1: 4.200656643454984 [repeated 3x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15144) SARX is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 6.452357601933096 Z_err_max1: 4.312344334903963
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17326, ip=192.168.1.5) Z_err_max: 6.122864219573893 Z_err_max1: 4.499916555491705
# (map_fun_fmle pid=15152) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15145) Z_err_max: 5.4503116106390515 Z_err_max1: 4.546112100449576 [repeated 2x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 6.48829574464965 Z_err_max1: 4.222379916803327
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 8.49407904345323 Z_err_max1: 3.573206268930647
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 4.997219992466108 Z_err_max1: 4.710716611116796
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17331, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) Z_err_max: 6.454022895424634 Z_err_max1: 4.43980190065499
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 4.80337574386901 Z_err_max1: 4.222346188101814
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 7.000441131840022 Z_err_max1: 3.682404814624697
# (map_fun_fmle pid=17320, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15147) cmle is over
# (map_fun_fmle pid=15147) Z_err_max: 5.9491556012665505 Z_err_max1: 5.025197195174717
# (map_fun_fmle pid=15373, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) Z_err_max: 5.194811042355051 Z_err_max1: 4.5143136939244695
# (map_fun_fmle pid=15377, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=17320, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15147) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=15151) fmle is over
# (map_fun_fmle pid=15373, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) Z_err_max: 6.559626407681045 Z_err_max1: 4.358103333933668
# (map_fun_fmle pid=15373, ip=192.168.1.8) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=15376, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) Z_err_max: 5.746088784497564 Z_err_max1: 5.999902126229345
# (map_fun_fmle pid=15370, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) Z_err_max: 5.537119558021173 Z_err_max1: 4.230772835709031
# (map_fun_fmle pid=15376, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15370, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15376, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15380, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) Z_err_max: 5.133267790659919 Z_err_max1: 3.5694003648373904
# (map_fun_fmle pid=17319, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) Z_err_max: 6.3669903011089755 Z_err_max1: 3.903836217877981
# (map_fun_fmle pid=15146) cmle is over
# (map_fun_fmle pid=15146) Z_err_max: 4.670663771475775 Z_err_max1: 4.639048974237223
# (map_fun_fmle pid=15372, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=17319, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15146) SARX is over
# (map_fun_fmle pid=15372, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) Z_err_max: 6.221741225224898 Z_err_max1: 2.820251489584187
# (map_fun_fmle pid=17319, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15146) fmle is over
# (map_fun_fmle pid=15371, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) Z_err_max: 5.846604971364885 Z_err_max1: 4.22936672744907
# (map_fun_fmle pid=17877, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) Z_err_max: 5.745402485601323 Z_err_max1: 3.7096085626093878
# (map_fun_fmle pid=17879, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) Z_err_max: 5.393021458517367 Z_err_max1: 5.546889519385655
# (map_fun_fmle pid=15371, ip=192.168.1.8) fmle is over
# (map_fun_fmle pid=17323, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) Z_err_max: 6.7300927687010415 Z_err_max1: 4.257471072504818
# (map_fun_fmle pid=17877, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) Z_err_max: 7.026830062514055 Z_err_max1: 3.8069811810839767
# (map_fun_fmle pid=17323, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17879, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17878, ip=192.168.1.6) Z_err_max: 7.658072408660507 Z_err_max1: 5.603045004282571
# (map_fun_fmle pid=15148) cmle is over
# (map_fun_fmle pid=15148) Z_err_max: 6.130763310366992 Z_err_max1: 3.556808798658111
# (map_fun_fmle pid=17879, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17881, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15144) cmle is over
# (map_fun_fmle pid=15144) Z_err_max: 7.19152097905357 Z_err_max1: 4.0941524395370745
# (map_fun_fmle pid=17878, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17877, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17875, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15152) cmle is over
# (map_fun_fmle pid=15152) Z_err_max: 4.523601757448754 Z_err_max1: 5.249911129491048
# (map_fun_fmle pid=15144) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17881, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) Z_err_max: 4.521700593439002 Z_err_max1: 4.70417632007097
# (map_fun_fmle pid=17878, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15152) SARX is over
# (map_fun_fmle pid=15152) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=17880, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) Z_err_max: 6.981143040212738 Z_err_max1: 3.7347728340345228
# (map_fun_fmle pid=15144) fmle is over
# (map_fun_fmle pid=17880, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) Z_err_max: 5.333274776351887 Z_err_max1: 3.163676087499171
# (map_fun_fmle pid=17318, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=17318, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17317, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15145) cmle is over
# (map_fun_fmle pid=15145) Z_err_max: 8.274706844479343 Z_err_max1: 3.6321493232239694
# (map_fun_fmle pid=17317, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) cmle is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) Z_err_max: 4.954606242498935 Z_err_max1: 4.609034209274943
# (map_fun_fmle pid=15145) SARX is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) Z_err_max: 6.710761128886038 Z_err_max1: 4.488304314223723
# (map_fun_fmle pid=17330, ip=192.168.1.5) SARX is over
# (map_fun_fmle pid=15145) fmle is over
# (map_fun_fmle pid=15150) cmle is over
# (map_fun_fmle pid=15150) Z_err_max: 4.758705836508185 Z_err_max1: 4.59276417424878
# (map_fun_fmle pid=17874, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=17330, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=17874, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15150) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) cmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) Z_err_max: 6.5072122832998875 Z_err_max1: 4.565802166699495
# (map_fun_fmle pid=15150) fmle is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) SARX is over
# (map_fun_fmle pid=15151) cmle is over
# (map_fun_fmle pid=15151) Z_err_max: 6.136087221140832 Z_err_max1: 4.871126423108862
# (map_fun_fmle pid=15147) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=15147) Z_err_max: 6.409089538501616 Z_err_max1: 2.901886472649576 [repeated 2x across cluster]
# (map_fun_fmle pid=15151) SARX is over
# (map_fun_fmle pid=17876, ip=192.168.1.6) fmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) cmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) Z_err_max: 6.999229902337101 Z_err_max1: 5.400573633435013
# (map_fun_fmle pid=15147) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=17326, ip=192.168.1.5) fmle is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) SARX is over
# (map_fun_fmle pid=15377, ip=192.168.1.8) fmle is over [repeated 2x across cluster]

# %%
print(ray.cluster_resources())
# Out:
# {'CPU': 124.0, 'memory': 184393276213.0, 'object_store_memory': 79025689803.0, 'node:192.168.1.6': 1.0, 'node:192.168.1.5': 1.0, 'node:192.168.1.8': 1.0, 'node:__internal_head__': 1.0, 'node:192.168.1.7': 1.0}

# %%
# Importing OS module for interacting with the operating system (e.g., file paths, directories)
import os

NUM_CPU = (ray.cluster_resources())['CPU'] #os.cpu_count() 

print(f'CPU total: {NUM_CPU}')
# Out:
# CPU total: 124.0

# %%
NUM_THREADS = 4

os.environ["MKL_NUM_THREADS"]     = str(NUM_THREADS)
os.environ["NUMEXPR_NUM_THREADS"] = str(NUM_THREADS)
os.environ["OMP_NUM_THREADS"]     = str(NUM_THREADS)

NUM_PROCESS = NUM_CPU // NUM_THREADS
print(f'max process: {NUM_PROCESS}')
# Out:
# max process: 31.0

# %% [markdown]
# ### True parameters and network setting

# %%
# Dimensions 
n = 500; p = 50; q = 20; d = 3

# %%
# true parameter
seed = 666
rng = np.random.default_rng(seed) 
tau = np.round(rng.uniform(0.15,0.2,p),4)
rho = np.round(rng.uniform(0.2,0.9,p),4)
beta0 = np.round(rng.uniform(0.5,1,(p,10)),4)
beta1 = np.zeros((p,q-10))
beta = np.hstack((beta0, beta1))
bc = np.array(np.hstack([rng.normal(0,1,(p,d))]))
# Omega mean and variance
mean = np.zeros(p)
ta = 0.15
i, j = np.mgrid[:p, :p]
cov = ta**2*ta**abs(i-j)
cov[list(range(p)),list(range(p))] = ta
sigma2 = np.zeros(p)
for j in range(p):
    sigma2[j] = bc[j,:]@bc[j,:] + ta

# %%
# Adjacency matrix-SBM
A = np.zeros((n,n))
K = 5
nk = int(n/K)
p1 = 9/n
p2 = 3/n
P = (np.kron(np.eye(K),(p1-p2)*np.ones((nk,nk)))+p2*np.ones((n,n))).flatten()
A = (rng.binomial(1,P)).reshape((n,n))

ind = (np.where(np.sum(A,1)==0))[0]
for i in ind:
    A[i,rng.choice(list(range(n)),6)] = 1
A[list(range(n)),list(range(n))] = 0
W = A/np.sum(A,1).reshape(n,1)

# %%
# check
print(np.sum(A))
np.max(np.sum(A,1))
# Out:
# 2114
# np.int64(13)

# %% [markdown]
# ### Save path setting and save parameters

# %%
Save_path_dir = '../results/Results_Block_02/'

# %%
#save true values
pd.DataFrame(rho).to_csv(Save_path_dir+f"n{n}_p{p}_B500/rho_true_n{n}_p{p}.csv",index=False)
pd.DataFrame(beta).to_csv(Save_path_dir+f"n{n}_p{p}_B500/beta_true_n{n}_p{p}.csv",index=False)
pd.DataFrame(bc).to_csv(Save_path_dir+f"n{n}_p{p}_B500/B_true_n{n}_p{p}.csv",index=False)
pd.DataFrame(A).to_csv(Save_path_dir+f"A_smallp_n{n}.csv",index=False)

# %% [markdown]
# ### Parallel framework-Ray and full process

# %%
# parallel computation framework
import ray

ray.init(num_cpus=NUM_CPU, ignore_reinit_error=True)
# Out:
# 2025-07-27 15:34:44,699	INFO worker.py:1747 -- Connecting to existing Ray cluster at address: 192.168.1.7:6379...
# 2025-07-27 15:34:44,700	INFO worker.py:1765 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='', python_version='3.12.4', ray_version='2.48.0', ray_commit='03491225d59a1ffde99c3628969ccf456be13efd')

# %%
# Randomly selected one dimension response for the CP
jj = rng.integers(0, p)
Save_path_process = os.path.abspath(Save_path_dir + 'process.txt')
Save_path_process_ci = os.path.abspath(Save_path_dir + 'process_ci.txt')

# %%
# Whole process
# Defining `map_fun_fmle` function, implementing a specific computational task
@ray.remote(num_cpus=4) 
def map_fun_fmle(bb):
    
    Y, X, Z = utils.data_generator(n, p, q, d, W, mean, cov, rho, beta, bc, seed = bb + 88)
    n0 = int(0.1*n)
    n1 = n - n0
    WW0 = W[:n0,:n0]
    Y0, X0, Z0 = Y[:n0], X[:n0,:], Z[:n0,:]  
    WW1 = W[n0:,n0:]
    Y1, X1, Z1 = Y[n0:], X[n0:,:], Z[n0:,:]
    # tic1n = time()
    #initial estimators
    rho_hi, beta_hi, sigma2_hi, ite_hi = utils.optimize_initial(n1, p, q, WW1, Y1, X1, bb, Save_path_process)
    rho_hb, beta_hb, sigma2_hb, ite_hb = utils.optimize_initial(n0, p, q, WW0, Y0, X0, bb, Save_path_process)
    print('cmle is over')
    # toc1n = time()
    # print(toc1n - tic1n)
    
    # Estimate Zi and M
    Z_h, M = utils.Z_est(n0, p, q, d, WW0, WW1, Y1, X1, rho_hi, beta_hi, Y0, X0, rho_hb, beta_hb)
    
    Z_err_max = np.max(abs(Z_h - Z1))
    Z_err_max1 = np.max(abs(-Z_h - Z1))
    print('Z_err_max:', Z_err_max, 'Z_err_max1:', Z_err_max1)
    if Z_err_max>Z_err_max1:
        Z_h = - Z_h
    if (Z_err_max>10) and (Z_err_max1>10):
        return np.zeros((8,p)),np.zeros(p),np.zeros(p),np.zeros(p)
    
    # FMLE with true Z
    rho_hfZ, beta_hfZ, b_hfZ, tau2_hfZ, ite_hfZ = utils.optimize(n1, p, q, d, WW1, Z1, Y1, X1, bb, Save_path_process)
    print('SARX is over')
    
    # FMLE with estimated Z
    rho_hf, beta_hf, b_hf, tau2_hf, ite_hf = utils.optimize(n1, p, q, d, WW1, Z_h, Y1, X1, bb, Save_path_process)
    print('fmle is over')

    H_hat = M.T@M/p
    bc_hat = b_hf.T@H_hat
    sigma2_hat = np.zeros(p)
    for j in range(p):
        sigma2_hat[j] = bc_hat[j,:]@bc_hat[j,:] + tau2_hf[j]

    lower_est = np.zeros(p)
    upper_est = np.zeros(p)
    q0 = 10
    # for j in range(p):
    #     tic1nj = time()
    #     lower_est[j], upper_est[j] = CI_est_new(j, n1, p, q0, d, WW1, rho_hf, beta_hf, b_hf, tau2_hf, M, sigma2_hat, Y1, X1, Z_h, 1.96)
    #     toc1nj = time()
    #     with open('Results_Block_02/process.txt', 'a') as f1:
    #         f1.write(str(bb)+', '+str(j)+', '+str(toc1nj - tic1nj)+', '+str(lower_est[j])+', '+str(upper_est[j])+'\n')   
    # CI computation
    tic1nj = time()
    lower_est[jj], upper_est[jj] = utils.CI_est_test(jj, n1, p, q0, d, WW1, rho_hf, beta_hf, b_hf, tau2_hf, M, sigma2_hat, Y1, X1, Z_h, 1.96)
    toc1nj = time()  
    with open(Save_path_process_ci, 'a') as f1:
        f1.write(str(bb)+', '+str(jj)+', '+str(toc1nj - tic1nj)+', '+str(lower_est[jj])+', '+str(upper_est[jj])+'\n')   
 

    return np.array([rho_hi, rho_hfZ, rho_hf, sigma2_hi, tau2_hfZ, tau2_hf, lower_est, upper_est]), ite_hi, ite_hfZ, ite_hf

# %%
from time import time
from numpy.random import default_rng

# %% [markdown]
# ### Start parallel experiments

# %%
# Whole experiments
BB = 500
tic1 = time()
tasks = [map_fun_fmle.remote(bb) for bb in range(BB)]
results500_p50whole = ray.get(tasks)  
toc1 = time()
print(toc1 - tic1) # Total time
# Out:
# 4303.228565454483

# %%
import ray
ray.shutdown()

# %% [markdown]
# ### Save results and analysis

# %%
# Save Results
BB = 500
q0 = 10
theta_hat_Block_n500_p50_B500 = np.zeros((BB,8,p))

ite_ini = np.zeros((BB,p))
ite_fZin = np.zeros((BB,p))
ite_fin = np.zeros((BB,p))
#tic1 = time()
for bt in range(BB):
    theta_hat_Block_n500_p50_B500[bt,:,:], ite_ini[bt,:], ite_fZin[bt,:], ite_fin[bt,:] = results500_p50whole[bt][0], results500_p50whole[bt][1],results500_p50whole[bt][2],results500_p50whole[bt][3]
#toc1 = time()

# %%
# ECP computation
cc = list(set(range(BB)).difference(set(np.where(ite_fin==0)[0])))
ECP = np.zeros(len(cc))
i=0
for b in cc:
    ECP[i] = (theta_hat_Block_n500_p50_B500[b,6,jj]<=rho[jj]) & (rho[jj]<=theta_hat_Block_n500_p50_B500[b,7,jj])
    i = i+1

# %%
np.mean(ECP)
# Out:
# np.float64(0.944)

# %%
#cmle
np.nanmean(abs(theta_hat_Block_n500_p50_B500[cc,0,:]-((rho.reshape((p,1))@np.ones((1,BB))).T)[cc,:]))
# Out:
# np.float64(0.034652235865416305)

# %%
#SARX
np.nanmean(abs(theta_hat_Block_n500_p50_B500[cc,1,:]-((rho.reshape((p,1))@np.ones((1,BB))).T)[cc,:]))
# Out:
# np.float64(0.010573491988717933)

# %%
#fmle
np.nanmean(abs(theta_hat_Block_n500_p50_B500[cc,2,:]-((rho.reshape((p,1))@np.ones((1,BB))).T)[cc,:]))
# Out:
# np.float64(0.021386851698667914)

# %%
# Save results
for b in range(BB):
    pd.DataFrame(theta_hat_Block_n500_p50_B500[b,:,:]).to_csv("../results/Results_Block_02/n500_p50_B500/theta_hat_Block_n500_p50_"+str(b)+'_.csv',index=False)
