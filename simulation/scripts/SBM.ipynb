# %%
import pandas as pd
import sys,codecs
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import scipy.stats as st
import collections
import statsmodels.api as sm
from time import time
import random

# %%
import os

NUM_CPU = len(os.sched_getaffinity(0)) #os.cpu_count() 

print(f'CPU total: {NUM_CPU}')
# Out:
# CPU total: 36

# %%
NUM_THREADS = 4

os.environ["MKL_NUM_THREADS"]     = str(NUM_THREADS)
os.environ["NUMEXPR_NUM_THREADS"] = str(NUM_THREADS)
os.environ["OMP_NUM_THREADS"]     = str(NUM_THREADS)

NUM_PROCESS = NUM_CPU // NUM_THREADS
print(f'max process: {NUM_PROCESS}')
# Out:
# max process: 9

# %%
# dimensions 
n = 500; p = 50; q = 20; d = 3

# %%
# true parameter
tau = np.round(np.random.uniform(0.15,0.2,p),4)
rho = np.round(np.random.uniform(0.2,0.9,p),4)
beta0 = np.round(np.random.uniform(0.5,1,(p,10)),4)
beta1 = np.zeros((p,q-10))
beta = np.hstack((beta0, beta1))
bc = np.array(np.hstack([np.random.normal(0,1,(p,d))]))
# Omega mean and variance
mean = np.zeros(p)
ta = 0.15
i, j = np.mgrid[:p, :p]
cov = ta**2*ta**abs(i-j)
cov[list(range(p)),list(range(p))] = ta
sigma2 = np.zeros(p)
for j in range(p):
    sigma2[j] = bc[j,:]@bc[j,:] + ta

# %%
# adjacency matrix-SBM
A = np.zeros((n,n))
K = 5
nk = int(n/K)
p1 = 9/n
p2 = 3/n
P = (np.kron(np.eye(K),(p1-p2)*np.ones((nk,nk)))+p2*np.ones((n,n))).flatten()
A = (np.random.binomial(1,P)).reshape((n,n))

ind = (np.where(np.sum(A,1)==0))[0]
for i in ind:
    A[i,random.sample(list(range(n)),6)] = 1
A[list(range(n)),list(range(n))] = 0
W = A/np.sum(A,1).reshape(n,1)

# %%
# check
print(np.sum(A))
np.max(np.sum(A,1))
# Out:
# 2144
# 11

# %%
#save true values
pd.DataFrame(rho).to_csv("Results_Block_02/n500_p50_B500/rho_true_n500_p50.csv",index=False)
pd.DataFrame(beta).to_csv("Results_Block_02/n500_p50_B500/beta_true_n500_p50.csv",index=False)
pd.DataFrame(bc).to_csv("Results_Block_02/n500_p50_B500/B_true_n500_p50.csv",index=False)
pd.DataFrame(A).to_csv("Results_Block_02/A_smallp_n500.csv",index=False)

# %%
# Data generation function
def data_generator(nn, p, q, d, seed):

    rng = np.random.default_rng(seed) 
    
    q0 = 10
    Omega = rng.multivariate_normal(mean, cov, (nn,), 'raise')   
    X = rng.normal(0,1,(nn,q0))
    Z = rng.normal(0,1,(nn,d))
    
    Y = np.zeros((n,p))
    for j in range(p):
        y_j = np.dot(np.linalg.inv(np.eye(nn)-rho[j]*W), X@beta[j,:q0] + Z@bc[j,:]+Omega[:,j])#
        Y[:,j] = y_j 
        
    return Y,X,Z

# %%
# CMLE-gradient
def gardient_initial_lj(nn, p, q, WW, para, Yj, XX):
    
    q0 = 10
    
    rho_j = para[0]
    beta_j = para[1:(q0+1)]
    sigma2_j = para[-1]
    
    
    Sj = np.eye(nn)-rho_j*WW
    S_inverse = np.linalg.inv(Sj)
    G = WW@S_inverse
    Ep = Sj@Yj - XX@beta_j
    
    g1 = -np.trace(G)+np.dot((WW@Yj).T,Ep)/sigma2_j
    g2 = (XX.T@Ep)/sigma2_j
    g3 = -nn/(2*sigma2_j)+(Ep.T@Ep)/(2*(sigma2_j**2))
    #print(Ep)
    
    return np.concatenate(([g1],g2,[g3]))

# %%
# CMLE-hessian
def hessian_initial_lj(nn, p, q, Wt, para, Yj, XX):
    
    q0 = 10
    
    #初始值
    rho_j = para[0]
    beta_j = para[1:(q0+1)]
    sigma2_j = para[-1]
    
    Sj = np.eye(nn)-rho_j*Wt
    S_inverse = np.linalg.inv(Sj)
    G = np.dot(Wt,S_inverse)
    WW = np.dot(Wt.T,Wt)
    WS = np.dot(Wt.T,Sj)
    SS = np.dot(Sj.T,Sj)
    Ep = Sj@Yj - XX@beta_j
    
    
    h11 = -np.trace(G@G)-np.dot(Yj.T@WW,Yj)/sigma2_j
    h12 = h21 = -(XX.T@(Wt@Yj)/sigma2_j).reshape(q0,1)
    h31 = h13 = -np.dot((Wt@Yj).T,Ep)/(sigma2_j**2)
    
    h22 = -XX.T@XX/sigma2_j
    h23 = h32 = -(XX.T@Ep/(2*sigma2_j**2)).reshape(q0,1)
    h33 = nn/(2*sigma2_j**2)-np.dot(Yj.T@SS,Yj)/(sigma2_j**3)
    
    H = np.block([
         [h11, h12.T, h13],
         [h21, h22, h23],
         [h31, h32.T, h33]
    ])
    
    return H

# %%
# Newton--CMLE
def newton_sea_initial(nn, p, q, Wt, pa0, Yj, XX, max_iter = 50, eps = 1e-4):
    
    q0 = 10
    pa_new = pa0
    for t in range(max_iter):
        pa_pre = pa_new
        gradient = gardient_initial_lj(nn, p, q, Wt, pa_pre, Yj, XX)/nn 
        hessian =  hessian_initial_lj(nn, p, q, Wt, pa_pre, Yj, XX)/nn 
        diff = np.linalg.solve(hessian+0.001*np.eye(q0+2),gradient)
        pa_new = pa_pre - diff 
        if pa_new[-1]<0.01: pa_new[-1] = 0.01
        if pa_new[0]>1: pa_new[0] = 0.95
        #print(np.max(abs(diff)))
        if np.linalg.norm(diff) < eps:
            break
            
    return pa_new,t+1

# %%
# SAR optimization function
def optimize_initial(nn, p, q, Wt,YY, XX,bb):
    
    q0 = 10
    para = np.zeros((q0+2,p))
    ite = np.zeros(p)
    par = np.zeros(q0+2)
    par[-1] = 0.1
    for j in range(p):
        res = newton_sea_initial(nn, p, q, Wt, par, YY[:,j], XX)
        para[:,j] = res[0]
        if para[0,j]> 0.95: 
            para[0,j] = 0.95
        if para[0,j]< 0.05: 
            para[0,j] = 0.05
        ite[j] = res[1]
        with open('Results_Block_02/process1.txt', 'a') as f1:
            f1.write(str(bb)+', initial: '+ str(j) + ', '+ str(para[0,j]) +'\n')
        #print('initial:',j, para[0,j])
    
    return para[0,:],para[1:(q0+1),:], para[-1,:],ite

# %%
# FMLE-gradient
def gardient_lj(nn, p, q, d, Wt,the0, Z_ee, Yj, XX):
    
    q0 = 10
    rhoj = the0[0]
    betaj = the0[1:(q0+1)]
    bj = the0[(q0+1):(q0+d+1)]
    tauj2 = the0[-1]
    
    Sj = np.eye(nn)-rhoj*Wt
    S_inverse = np.linalg.inv(Sj)
    G = Wt@S_inverse
    Ep = Sj@Yj - XX@betaj - Z_ee@bj
    
    g1 = -np.trace(G)+np.dot((Wt@Yj).T,Ep)/tauj2
    g2 = (XX.T@Ep)/tauj2
    g3 = (Z_ee.T@Ep)/tauj2
    g4 = -nn/(2*tauj2)+(Ep.T@Ep)/(2*tauj2**2)
    
    return np.concatenate(([g1],g2,g3,[g4]))

# %%
# FMLE-hessian
def hessian_lj(nn, p, q, d, Wt, the0, Z_e, Yj, XX):
    
    q0 = 10
    rhoj = the0[0]
    betaj = the0[1:(q0+1)]
    bj = the0[(q0+1):(q0+d+1)]
    tauj2 = the0[-1]
    
    Sj = np.eye(nn)-rhoj*Wt
    S_inverse = np.linalg.inv(Sj)
    G = np.dot(Wt,S_inverse)
    WY = Wt@Yj
    Ep = Sj@Yj - XX@betaj - Z_e@bj
    
    h11 = -np.trace(G@G) - WY.T@WY/tauj2
    
    h12 = h21 = -(XX.T@WY/tauj2).reshape(q0,1)
    h13 = h31 = -(Z_e.T@WY/tauj2).reshape(d,1)
    h14 = h41 = -WY.T@Ep/tauj2**2
    
    h22 = -XX.T@XX/tauj2
    h23 = h32 = -XX.T@Z_e/tauj2
    h24 = h42 = -(XX.T@Ep/(2*tauj2**2)).reshape(q0,1)
    
    h33 = -Z_e.T@Z_e/tauj2
    h34 = h43 = -(Z_e.T@Ep/(2*tauj2**2)).reshape(d,1)
    
    h44 = nn/(2*tauj2**2)-Ep.T@Ep/(tauj2**3)
    
    H = np.block([
         [h11, h12.T, h13.T, h14],
         [h21, h22, h23, h24],
         [h31, h32.T, h33, h34],
         [h41, h42.T, h43.T, h44]
    ])
    
    return H

# %%
# Newton--FMLE
def newton_sea(nn, p, q, d, Wt, theta0, Z_e, Yj, Xt, max_iter = 50, eps = 1e-4):
    
    q0 = 10
    theta_new = theta0
    for t in range(max_iter):
        theta_pre = theta_new
        gradient = gardient_lj(nn, p,q,d,Wt, theta_pre, Z_e, Yj,Xt)/nn 
        hessian =  hessian_lj(nn, p,q,d,Wt, theta_pre, Z_e, Yj,Xt)/nn 
        diff = np.linalg.solve(hessian+0.001*np.eye(q0+d+2),gradient)
        #print(np.max(abs(diff)))
        theta_new = theta_pre - diff
        if theta_new[-1]<0.01: theta_new[-1] = 0.01
        if theta_new[0]>1: theta_new[0] = 0.95

        if np.linalg.norm(diff) < eps:
            break
            
    return theta_new,t+1

# %%
# FMLE optimization function
def optimize(nn, p, q, d, Wt, Z_e, Yt, Xt,bb):
    
    q0 = 10
    g = q0+d+2
    theta = np.zeros((g,p))
    itee = np.zeros(p)
    theta0 = np.zeros(g)
    theta0[-1] = 0.1
    for j in range(p):
        res = newton_sea(nn, p, q, d, Wt, theta0, Z_e, Yt[:,j], Xt)
        theta[:,j] = res[0]
        itee[j] = res[1]
        if theta[0,j]> 0.95: 
            theta[0,j] = 0.95
        if theta[0,j]< 0.05: 
            theta[0,j] = 0.05
        with open('Results_Block_02/process1.txt', 'a') as f1:
            f1.write(str(bb)+', update: '+ str(j) + ', '+ str(theta[0,j]) +'\n')
        #print('update:',j, theta[0,j])
    
    return theta[0,:],theta[1:(q0+1),:],theta[(q0+1):(q0+d+1),:], theta[-1,:], itee

# %%
# Factor estimation function
def Z_est(nn, p, q, d, Wt0, Wt1, Y_1, X_1, rho_e, beta_e, Yb, Xb, rho_hb, beta_hb):
    
    Eb = Yb - (Wt0@Yb)@np.diag(rho_hb) - Xb@beta_hb
    Sigm = Eb.T@Eb/nn 
    U, G, V = np.linalg.svd(Sigm)
    M = U[:,:d]@np.diag(G[:d])**0.5
    
    E = Y_1 - (Wt1@Y_1)@np.diag(rho_e) - X_1@beta_e
     
    Z_e = E@M/p
    
    return Z_e, M

# %%
# Confidence interval for FMLE
def CI_est_test(j,nn, p, q0, d, WW, rho_est, beta_est, b_est, tau2_est, B_hat, sigma2_hat, YY, XX, Z_est, z_alpha):
    
    # ticn1 = time()
    S = np.eye(nn)-rho_est[j]*WW
    S_inverse = np.linalg.inv(S)
    G = np.dot(WW,S_inverse)
    Gs = G + G.T
    GXbe = G@XX@beta_est[:,j]
    GZb = G@Z_est@b_est[:,j]

    c1 = tau2_est[j]*np.trace(G@Gs)
    c21 = GXbe + GZb
    C11 = c1 + c21.T@c21
    C12 = C21 = (XX.T@GXbe).reshape(q0,1)
    C13 = C31 = (Z_est.T@GZb).reshape(d,1)
    C14 = C41 = np.trace(G)
    C22 = XX.T@XX
    C23 = C32 = XX.T@Z_est
    C24 = C42 = np.zeros((q0,1))
    C33 = Z_est.T@Z_est
    C34 = C43 = np.zeros((d,1))
    C44 = nn/(2*tau2_est[j])
            
    Sigma2 = np.block([
             [C11, C12.T, C13.T, C14],
             [C21, C22, C23, C24],
             [C31, C32.T, C33, C34],
             [C41, C42.T, C43.T, C44],
        ])/(nn*tau2_est[j])
    
    Sigma2_inv = np.linalg.inv(Sigma2)
    # tocn1 = time()
    # print(tocn1 - ticn1) 
    
    g = q0+d+2
    Mbtj = B_hat@b_est[:,j]
    Omega_hat = S@YY[:,j] - XX@beta_est[:,j] - Z_est@b_est[:,j]
    Aj = np.zeros((nn*d,g*nn*d))
    Dj = np.zeros((nn*d,g))
    for k in range(p):
        Sk = np.eye(nn)-rho_est[k]*WW
        S_inverse = np.linalg.inv(Sk)
        G = np.dot(WW,S_inverse)
        GXbeta = G@XX@beta_est[:,k]
        
        C11 = np.trace(G@(G+G.T)) + GXbeta.T@GXbeta/sigma2_hat[k]
        C12 = C21 = (XX.T@GXbeta/sigma2_hat[k]).reshape(q0,1)
        C13 = C31 = np.trace(G)/sigma2_hat[k]
        C22 = XX.T@XX/sigma2_hat[k]
        C23 = C32 = np.zeros((q0,1))
        C33 = nn/(2*sigma2_hat[k]**2)
        
        Sigma = np.block([
             [C11, C12.T, C13],
             [C21, C22, C23],
             [C31, C32.T,C33]
        ])/nn
        H = np.linalg.inv(Sigma)
        H_rho = H[0,:]
        H_beta = H[1:-1,:]
    
        A2 = G.T/sigma2_hat[k]
        A3 = np.eye(nn)/(2*sigma2_hat[k]**2)
        A1 = H_rho[0]*A2 + H_rho[-1]*A3
        
    
        cjk_rho = YY[:,j].T@WW.T@WW@YY[:,k]*Mbtj[k]/nn
        cjk_beta = XX.T@WW@YY[:,k]*Mbtj[k]/nn
        cjk_b = Z_est.T@WW@YY[:,k]*Mbtj[k]/nn - B_hat[k,:]*(Omega_hat@WW@YY[:,k])/nn
        cjk_tau2 = Omega_hat@WW@YY[:,k]*Mbtj[k]/(nn*tau2_est[j])
        Qjk_rho = (XX.T@WW@YY[:,j]*Mbtj[k]/nn).reshape(q0,1)
        Qjk_beta = XX.T@XX*Mbtj[k]/nn # q0 c q0
        Qjk_b = XX.T@Z_est*Mbtj[k]/nn - (XX.T@Omega_hat).reshape(q0,1)@B_hat[k,:].reshape(1,d)/nn # q0 c d
        Qjk_tau2 = (XX.T@Omega_hat*Mbtj[k]/(nn*tau2_est[j])).reshape(q0,1)
        cjk_Theta = np.hstack([cjk_rho, cjk_beta, cjk_b, cjk_tau2]) #  g
        Qjk_Theta = np.concatenate([Qjk_rho, Qjk_beta, Qjk_b, Qjk_tau2], axis=1) # q0 c g
        
        vjk1 = cjk_Theta # g 
        vjk2 = Qjk_Theta.T@H_beta[:,0] # g 
        vjk3 = Qjk_Theta.T@H_beta[:,-1] # g 
        
        Ak = np.kron(A1, vjk1.reshape(1,g)) + np.kron(A2, vjk2.reshape(1,g)) + np.kron(A1, vjk3.reshape(1,g))
        Akb = np.kron(b_est[:,k].reshape(d,1)@b_est[:,k].reshape(1,d), Ak)
        Aj = Aj + Akb/p
    
        vjk = (cjk_Theta*H_rho[0] + Qjk_Theta.T@H_beta[:,0])/sigma2_hat[k] # g
        Ujk = (cjk_Theta.reshape(g,1)@H_beta[:,0].reshape(1,q0) + Qjk_Theta.T@H_beta[:,1:-1])/sigma2_hat[k] # g c q0
        Djk = GXbeta.reshape(nn,1)@vjk.reshape(1,g) + XX@Ujk.T # n c g
        Djkb = np.kron(b_est[:,k].reshape(d,1), Djk)
        Dj = Dj + Djkb/p

    # tocn1 = time()
    # print(tocn1 - ticn1)

    Sigma_Q = np.zeros((g, g))
    H_hat = B_hat.T @ B_hat / p
    HI = np.kron(H_hat @ H_hat.T, np.eye(nn))
    Z_hat = Z_est @ np.linalg.inv(H_hat)
    mu3z = np.mean(Z_hat**3)
    mu4z = np.mean(Z_hat**4)
    I_nd = np.eye(nn * d)
    D_matrix = Dj @ np.eye(g)  
    for i1 in range(g):
        Dbej1 = D_matrix[:, i1]
        Abej1 = Aj @ np.kron(I_nd, np.eye(g)[:, i1].reshape(g, 1))  
        diag_Abej1 = np.diag(Abej1)

        for i2 in range(g):
            # ticnn1 = time()
            Dbej2 = D_matrix[:, i2]
            Abej2 = Aj @ np.kron(I_nd, np.eye(g)[:, i2].reshape(g, 1))
            diag_Abej2 = np.diag(Abej2)

            VQ1 = Dbej1.T @ HI @ Dbej2
            VQ2 = np.trace(Abej1 @ HI @ (Abej2 + Abej2.T) @ HI)
            VQ3 = mu3z * (np.sum(diag_Abej1 * Dbej2) + np.sum(diag_Abej2 * Dbej1))
            VQ4 = mu4z * np.sum(diag_Abej1 * diag_Abej2)

            Sigma_Q[i1, i2] = (VQ1 + VQ2 + VQ3 + VQ4) / (nn * tau2_est[j]**2)
            # tocnn1 = time()
            # print(tocnn1 - ticnn1)

    # tocn1 = time()
    # print(tocn1 - ticn1) 
    # print(Sigma_Q)
    Sigma_Q2 = Sigma2_inv@Sigma_Q@Sigma2_inv
    sig = Sigma2_inv[0,0] + Sigma_Q2[0,0]
    
    lower = rho_est[j] - z_alpha*sig**0.5/nn**0.5
    upper = rho_est[j] + z_alpha*sig**0.5/nn**0.5

    
    return lower,upper

# %%
pip install ray

# %%
pip install -U ipywidgets

# %%
# parallel computation framework
import ray

ray.init(num_cpus=NUM_CPU, ignore_reinit_error=True)
# Out:
# 2025-04-27 05:40:14,547	INFO worker.py:1672 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.43.0', ray_commit='ecdcdc6a6e63dc4bcd6ea16aae256ce4d32a7e2c')

# %%
jj = random.randint(0, p)

# %%
# 整体过程
@ray.remote(num_cpus=4) 
def map_fun_fmle(bb):
    
    Y, X, Z = data_generator(n, p, q, d, seed = bb+88)
    n0 = int(0.1*n)
    n1 = n - n0
    WW0 = W[:n0,:n0]
    Y0, X0, Z0 = Y[:n0], X[:n0,:], Z[:n0,:]  
    WW1 = W[n0:,n0:]
    Y1, X1, Z1 = Y[n0:], X[n0:,:], Z[n0:,:]
    # tic1n = time()
    #initial estimators
    rho_hi, beta_hi, sigma2_hi, ite_hi = optimize_initial(n1, p, q, WW1, Y1, X1, bb)
    rho_hb, beta_hb, sigma2_hb, ite_hb = optimize_initial(n0, p, q, WW0, Y0, X0, bb)
    print('cmle is over')
    # toc1n = time()
    # print(toc1n - tic1n)
    
    # Estimate Zi and M
    Z_h, M = Z_est(n0, p, q, d, WW0, WW1, Y1, X1, rho_hi, beta_hi, Y0, X0, rho_hb, beta_hb)
    
    Z_err_max = np.max(abs(Z_h - Z1))
    Z_err_max1 = np.max(abs(-Z_h - Z1))
    print('Z_err_max:', Z_err_max, 'Z_err_max1:', Z_err_max1)
    if Z_err_max>Z_err_max1:
        Z_h = - Z_h
    if (Z_err_max>10) and (Z_err_max1>10):
        return np.zeros((8,p)),np.zeros(p),np.zeros(p),np.zeros(p)
    
    # FMLE with true Z
    rho_hfZ, beta_hfZ, b_hfZ, tau2_hfZ, ite_hfZ = optimize(n1, p, q, d,WW1, Z1, Y1,X1,bb)
    print('SARX is over')
    
    # FMLE with estimated Z
    rho_hf, beta_hf, b_hf, tau2_hf, ite_hf = optimize(n1, p, q, d, WW1, Z_h, Y1, X1, bb)
    print('fmle is over')

    H_hat = M.T@M/p
    bc_hat = b_hf.T@H_hat
    sigma2_hat = np.zeros(p)
    for j in range(p):
        sigma2_hat[j] = bc_hat[j,:]@bc_hat[j,:] + tau2_hf[j]

    lower_est = np.zeros(p)
    upper_est = np.zeros(p)
    q0 = 10
    # for j in range(p):
    #     tic1nj = time()
    #     lower_est[j], upper_est[j] = CI_est_new(j, n1, p, q0, d, WW1, rho_hf, beta_hf, b_hf, tau2_hf, M, sigma2_hat, Y1, X1, Z_h, 1.96)
    #     toc1nj = time()
    #     with open('Results_Block_02/process.txt', 'a') as f1:
    #         f1.write(str(bb)+', '+str(j)+', '+str(toc1nj - tic1nj)+', '+str(lower_est[j])+', '+str(upper_est[j])+'\n')   
    tic1nj = time()
    lower_est[jj], upper_est[jj] = CI_est_test(jj, n1, p, q0, d, WW1, rho_hf, beta_hf, b_hf, tau2_hf, M, sigma2_hat, Y1, X1, Z_h, 1.96)
    toc1nj = time()  
    with open('Results_Block_02/process_ci.txt', 'a') as f1:
        f1.write(str(bb)+', '+str(jj)+', '+str(toc1nj - tic1nj)+', '+str(lower_est[jj])+', '+str(upper_est[jj])+'\n')   
 

    return np.array([rho_hi, rho_hfZ, rho_hf, sigma2_hi, tau2_hfZ, tau2_hf, lower_est, upper_est]), ite_hi, ite_hfZ, ite_hf

# %%
from time import time
from numpy.random import default_rng

# %%
BB = 500
tic1 = time()
tasks = [map_fun_fmle.remote(bb) for bb in range(BB)]
results500_p50whole = ray.get(tasks)  # 等待所有任务完成
toc1 = time()
print(toc1 - tic1) # 总的计算时间
# Out:
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.195313302568559 Z_err_max1: 3.3115909381230813
# (map_fun_fmle pid=3050) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3050) Z_err_max: 7.006875051918519 Z_err_max1: 4.862208269316308 [repeated 3x across cluster]
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.945674951303354 Z_err_max1: 6.737715507257372
# (map_fun_fmle pid=3343) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3258) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.938689635138605 Z_err_max1: 4.144365578351785
# (map_fun_fmle pid=3258) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) cmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=3053) Z_err_max: 5.468790714061582 Z_err_max1: 4.627178144510777 [repeated 4x across cluster]
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3053) SARX is over [repeated 4x across cluster]
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3091) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3052) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.764763024418197 Z_err_max1: 3.988437172935167
# (map_fun_fmle pid=3290) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3290) Z_err_max: 6.575647363364521 Z_err_max1: 5.29351406720687 [repeated 3x across cluster]
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3290) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.122209751093426 Z_err_max1: 4.761042795921661
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.620663133356148 Z_err_max1: 5.37987684412599
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.41452916387142 Z_err_max1: 4.704765672792656
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3202) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3202) Z_err_max: 7.513961740693437 Z_err_max1: 4.8785792256796405 [repeated 3x across cluster]
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3202) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=3091) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 3.510324927548268 Z_err_max1: 4.742745873612802
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3343) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3343) Z_err_max: 6.340556724526439 Z_err_max1: 3.7651289771051233 [repeated 2x across cluster]
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3343) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3343) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.145689882480292 Z_err_max1: 5.462520802505754
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.679180219724266 Z_err_max1: 5.339426453697698
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 3.844726552998714 Z_err_max1: 6.378720814884432
# (map_fun_fmle pid=3202) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.822940012217737 Z_err_max1: 3.1712314478539496
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.411854992077297 Z_err_max1: 4.751487523571436
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 4.947095378648662 Z_err_max1: 4.89313942548546
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.328545873154237 Z_err_max1: 4.74595149192937
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.207419878839371 Z_err_max1: 5.227179439286163
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.478851651713876 Z_err_max1: 4.510859526821409
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 4.981945052889718 Z_err_max1: 4.873274981890414
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 2.8939099415538374 Z_err_max1: 5.388644112141441
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.6261202114669295 Z_err_max1: 5.9819880989271965
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.097284856143116 Z_err_max1: 4.052739660737182
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.5116262131365374 Z_err_max1: 4.245081782374105
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 5.724286106450606 Z_err_max1: 4.718561447972268
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.453768192253326 Z_err_max1: 3.9110475007439094
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.451485944830839 Z_err_max1: 3.4887378460466536
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.537214428188118 Z_err_max1: 4.109101029511229
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.602170096678204 Z_err_max1: 3.525586211090732
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.110689308465178 Z_err_max1: 4.63605480831704
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.2179242123781675 Z_err_max1: 3.371996172641928
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3090) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3090) Z_err_max: 7.038162986170903 Z_err_max1: 3.354669257446848 [repeated 3x across cluster]
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.4014348799935785 Z_err_max1: 3.8306701184304837
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 8.472799576027391 Z_err_max1: 3.9463579407041767
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.415730916823144 Z_err_max1: 3.9468814019349017
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.380652805701199 Z_err_max1: 4.68079552306727
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 9.22546438854517 Z_err_max1: 6.187140584886542
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) Z_err_max: 3.4253878040303727 Z_err_max1: 7.090431157159322 [repeated 2x across cluster]
# (map_fun_fmle pid=3055) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 3.935252701630634 Z_err_max1: 5.851825475372198
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3290) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.213119938493166 Z_err_max1: 6.652173603051931
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 6.7747521051804505 Z_err_max1: 4.591216359233339
# (map_fun_fmle pid=3090) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3090) Z_err_max: 6.10022223276475 Z_err_max1: 4.897783908936672 [repeated 2x across cluster]
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.083350687455228 Z_err_max1: 5.110509325890763
# (map_fun_fmle pid=3090) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.197353506330709 Z_err_max1: 4.926542047489625
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3091) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.846403218650726 Z_err_max1: 4.245523179917858
# (map_fun_fmle pid=3290) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3290) Z_err_max: 5.67057572821681 Z_err_max1: 5.025849331963159 [repeated 2x across cluster]
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.498733435611013 Z_err_max1: 4.865905800483363
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 3.763660681536789 Z_err_max1: 5.181409683978297
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.8651185111932485 Z_err_max1: 4.556080140238729
# (map_fun_fmle pid=3290) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3290) Z_err_max: 5.218868372662487 Z_err_max1: 5.15883044350478 [repeated 2x across cluster]
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3290) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 6.607305510772412 Z_err_max1: 5.505084018188617
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3202) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3202) Z_err_max: 4.242858561000553 Z_err_max1: 5.580472170061944 [repeated 2x across cluster]
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.2595142138092585 Z_err_max1: 3.5508744245726436
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.048605200400054 Z_err_max1: 5.451112171310603
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.125540714203073 Z_err_max1: 5.28447306074683
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.10256121219306 Z_err_max1: 5.082110163082556
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.205364090088532 Z_err_max1: 4.836486598334658
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.99292340039549 Z_err_max1: 5.044190603561134
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.149560877542866 Z_err_max1: 3.1006854174557024
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.215091381116572 Z_err_max1: 4.874462548950624
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 7.062487607161636 Z_err_max1: 5.2173833914916194
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.009189962189835 Z_err_max1: 5.485388120047581
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.684853439644063 Z_err_max1: 3.68195799438936
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 4.592742221252099 Z_err_max1: 3.1378184614960722
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.098532576591921 Z_err_max1: 4.911218486046637
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.345113315625587 Z_err_max1: 4.59115374141785
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.204468607253171 Z_err_max1: 4.212140735711176
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 7.227197612274351 Z_err_max1: 4.861283370204426
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.2745107318199365 Z_err_max1: 3.365200295296976
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.9721895261205 Z_err_max1: 4.2274673743936
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.949758759125378 Z_err_max1: 6.299926770669808
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.220499937524007 Z_err_max1: 5.3500144232783775
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.140479860289345 Z_err_max1: 5.065286436876461
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.253655214459382 Z_err_max1: 5.808411976515725
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.4580796231329405 Z_err_max1: 4.811681304771964
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3202) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3202) Z_err_max: 5.35522900147504 Z_err_max1: 3.503330374131616 [repeated 2x across cluster]
# (map_fun_fmle pid=3090) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.79751660330201 Z_err_max1: 4.743675156707474
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.394919598613475 Z_err_max1: 5.16078204156517
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3090) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 7.306215550847002 Z_err_max1: 3.392522893955983
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.514349972457067 Z_err_max1: 4.586935824958029
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.679293425218919 Z_err_max1: 4.818798440648866
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.320766180512548 Z_err_max1: 5.639840271457107
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.650740335054647 Z_err_max1: 5.179634028427925
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 6.547683112927427 Z_err_max1: 5.94546996581056
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.750417002844873 Z_err_max1: 4.159770508357516
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 4.950651134400074 Z_err_max1: 4.82113350983192
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.874469665583199 Z_err_max1: 5.696951582919316
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.603781477926109 Z_err_max1: 4.967571885149672
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.5251827289900675 Z_err_max1: 2.60556290882223
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.897767737649104 Z_err_max1: 5.311598778650808
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.739981999678363 Z_err_max1: 4.255361814724093
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 7.571452613731289 Z_err_max1: 5.329919462869339
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 4.44528127709551 Z_err_max1: 4.711750622846865
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.183896666685281 Z_err_max1: 4.864462946221637
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 3.7533436297555154 Z_err_max1: 5.782964142348425
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 6.231379612730544 Z_err_max1: 4.17703840596161
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 4.587820547796186 Z_err_max1: 4.5801969996956675
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.288246991518854 Z_err_max1: 2.67066068282212
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.948341321656699 Z_err_max1: 4.270222607568256
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 4.9422275125837025 Z_err_max1: 6.65031411999806
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.655979879372449 Z_err_max1: 3.648905665082368
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.085313103210618 Z_err_max1: 5.056333902601886
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.281804709776804 Z_err_max1: 5.50444165702824
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.009610937594306 Z_err_max1: 4.759877730942407
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 7.293688950502031 Z_err_max1: 3.483028814225342
# (map_fun_fmle pid=3290) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3258) Z_err_max: 5.6364731222741895 Z_err_max1: 5.462513056383992
# (map_fun_fmle pid=3290) Z_err_max: 5.899233778846952 Z_err_max1: 4.744601694847241
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 2.3741305749954718 Z_err_max1: 7.120789698039453
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3050) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 6.135762396146434 Z_err_max1: 4.5117137427660765
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.318901960574827 Z_err_max1: 4.419818406575975
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 7.2630792658435155 Z_err_max1: 5.161835562171796
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 3.463662821371508 Z_err_max1: 4.884613103368567
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.952077562870249 Z_err_max1: 5.8910070819962765
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.886421614645318 Z_err_max1: 5.112434300370412
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.322088425713629 Z_err_max1: 5.251110227774406
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.252209120597144 Z_err_max1: 4.378994289244249
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.716905750157894 Z_err_max1: 5.555664113145217
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.208085950406737 Z_err_max1: 4.36548759497475
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 6.9237187883776965 Z_err_max1: 5.036277028684463
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3091) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) Z_err_max: 5.203343721358706 Z_err_max1: 3.5767849086666423 [repeated 2x across cluster]
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 3.619309010513086 Z_err_max1: 5.648607828986005
# (map_fun_fmle pid=3091) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.942096515127384 Z_err_max1: 5.379570240259174
# (map_fun_fmle pid=3090) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.694881138353514 Z_err_max1: 5.33474111904129
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.866084092212994 Z_err_max1: 4.055260738895113
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.26833898598732 Z_err_max1: 4.709980732565472
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) Z_err_max: 6.3236272295362665 Z_err_max1: 4.663241960155972 [repeated 2x across cluster]
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3050) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.589306557958009 Z_err_max1: 3.5702383970312193
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) cmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=3091) Z_err_max: 7.140237978731488 Z_err_max1: 4.611060241950266 [repeated 4x across cluster]
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3090) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.174595384336298 Z_err_max1: 3.767760992770326
# (map_fun_fmle pid=3091) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.78938904541838 Z_err_max1: 5.038489926273389
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.811014593916754 Z_err_max1: 6.47396497147173
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.663176908938427 Z_err_max1: 6.094746348347846
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.134161162371077 Z_err_max1: 4.129176712364362
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 4.7947614887726315 Z_err_max1: 5.014991469750165
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.716034556922887 Z_err_max1: 5.361218937204844
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 3.0622479668456584 Z_err_max1: 5.4085320019552885
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.886553571714279 Z_err_max1: 4.6172199031645675
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.357017206184228 Z_err_max1: 5.584246135016743
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.590533392191478 Z_err_max1: 5.853186105157384
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.817395493555788 Z_err_max1: 6.715806436705519
# (map_fun_fmle pid=3290) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3290) Z_err_max: 5.412696145714007 Z_err_max1: 5.139791275826377 [repeated 2x across cluster]
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.064714284721383 Z_err_max1: 3.8880762750833933
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.857533810452346 Z_err_max1: 6.253387982626091
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 4.2651488119797305 Z_err_max1: 4.899303232427991
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 7.406506518793549 Z_err_max1: 4.659354385117369
# (map_fun_fmle pid=3091) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) Z_err_max: 6.589855290460816 Z_err_max1: 4.376799513971333 [repeated 2x across cluster]
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.606636392158333 Z_err_max1: 4.965627871283871
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.057500384292247 Z_err_max1: 4.627517744011051
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.5683503986914005 Z_err_max1: 4.464899555527362
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.67614622079746 Z_err_max1: 4.741461164585708
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.5727265076017405 Z_err_max1: 6.789540224946484
# (map_fun_fmle pid=3258) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.452077291617717 Z_err_max1: 6.7578809746610835
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.9044343599516385 Z_err_max1: 3.908890738773831
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.463837680278677 Z_err_max1: 4.033937447225095
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.997779595367657 Z_err_max1: 3.107556028154543
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.149819620944259 Z_err_max1: 5.038122970917371
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.1319058555057815 Z_err_max1: 3.381194467186061
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 7.333848609442837 Z_err_max1: 3.9172518407403243
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) Z_err_max: 5.477269883838176 Z_err_max1: 5.283484177577051 [repeated 2x across cluster]
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.652704159813077 Z_err_max1: 4.852193208769908
# (map_fun_fmle pid=3091) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.024690216361337 Z_err_max1: 5.028262817945254
# (map_fun_fmle pid=3091) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.10814642741427 Z_err_max1: 3.1163117871935833
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 7.104895229849395 Z_err_max1: 5.2734165095857115
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.376710417611282 Z_err_max1: 6.682117848251377
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.661535341262747 Z_err_max1: 6.055730315841384
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.24321016389384 Z_err_max1: 4.934650911030618
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.1548704798943135 Z_err_max1: 5.028618461325394
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.564188202424784 Z_err_max1: 5.21536120451259
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.648077348489091 Z_err_max1: 6.098856551665778
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.579998412910252 Z_err_max1: 4.057686797171695
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.277460143723225 Z_err_max1: 4.720569810539603
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.838490362432265 Z_err_max1: 5.3028983976298525
# (map_fun_fmle pid=3290) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3290) Z_err_max: 5.4852653577837955 Z_err_max1: 6.064465060207755 [repeated 2x across cluster]
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.049379524590666 Z_err_max1: 4.58310255021104
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 4.830332442506732 Z_err_max1: 4.221620110286398
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 7.343437529138212 Z_err_max1: 3.1083418821946562
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.470440381521198 Z_err_max1: 3.8043719403090797
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.774811930266562 Z_err_max1: 4.723742380946964
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.289207966307165 Z_err_max1: 4.39879783534787
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3091) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) Z_err_max: 3.955528508058419 Z_err_max1: 4.688684147526434 [repeated 2x across cluster]
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.486874379114581 Z_err_max1: 5.499580797279849
# (map_fun_fmle pid=3202) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.883820394994032 Z_err_max1: 5.388643605907327
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3091) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.397898820740908 Z_err_max1: 4.507596152168276
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.174863022140192 Z_err_max1: 3.946048058909727
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.271448619423044 Z_err_max1: 5.110000416260248
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.848107547625963 Z_err_max1: 5.175584856886902
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.126309504226977 Z_err_max1: 4.8696324982341945
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 4.961866236854608 Z_err_max1: 5.805206656584335
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.321707876961447 Z_err_max1: 6.3109055659710735
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 4.5567232307462895 Z_err_max1: 6.076167248929882
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.3552843441486715 Z_err_max1: 5.0301776827668485
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 7.483537997213105 Z_err_max1: 3.154549769619259
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.636099807597902 Z_err_max1: 4.258294815612784
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.855095109001756 Z_err_max1: 4.318753627736445
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.857550211407766 Z_err_max1: 5.838258088412207
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.226492389543209 Z_err_max1: 4.466996751811788
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 5.458840733836912 Z_err_max1: 4.065344734288309
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.253416948961698 Z_err_max1: 4.97475642106689
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 8.037262048331144 Z_err_max1: 4.511066116004078
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.583506718995566 Z_err_max1: 3.8082698275478126
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.474882464979675 Z_err_max1: 3.585227245611452
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.520008991426639 Z_err_max1: 5.3249470817148
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.685206938629102 Z_err_max1: 5.406613177198713
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.6199480288591595 Z_err_max1: 5.16850674263814
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 4.114983038178183 Z_err_max1: 5.9867258421067815
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3290) Z_err_max: 6.447555527901814 Z_err_max1: 4.506302552219835
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.368498977398945 Z_err_max1: 4.784627752165792
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.862685402666147 Z_err_max1: 4.165331634765705
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 2.672578646162148 Z_err_max1: 6.07198634192884
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 7.24730912093175 Z_err_max1: 5.931536435242781
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.05506729742471 Z_err_max1: 3.1137925704602374
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.239426111730436 Z_err_max1: 5.643987507207552
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.272496307215576 Z_err_max1: 4.31404763206323
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.400401624165923 Z_err_max1: 6.6073120042447595
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 4.056589338479832 Z_err_max1: 5.274299324544913
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 4.895067695173838 Z_err_max1: 4.174954771311521
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.144692660388279 Z_err_max1: 5.77564824136029
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 4.911420538805865 Z_err_max1: 4.443545425322865
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.747432796356723 Z_err_max1: 4.8005117138622
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.389262025962177 Z_err_max1: 4.451847245758682
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.155613328874393 Z_err_max1: 5.489758780413117
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 5.293598672656666 Z_err_max1: 5.642456307643672
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.593451157792451 Z_err_max1: 7.568597738526817
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.64530730680736 Z_err_max1: 4.05961213095692
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.66274392979387 Z_err_max1: 2.7620443187807466
# (map_fun_fmle pid=3258) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3258) Z_err_max: 4.055091753897037 Z_err_max1: 5.125276491438266 [repeated 2x across cluster]
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.69694554650491 Z_err_max1: 6.4746879551093555
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.173677037688944 Z_err_max1: 5.183204779227557
# (map_fun_fmle pid=3091) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3053) Z_err_max: 6.419575399685979 Z_err_max1: 3.9120366810386464 [repeated 3x across cluster]
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3202) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3055) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# ...
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 4.7874396935094214 Z_err_max1: 4.193023826291726
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 7.1828584765392876 Z_err_max1: 4.471979256693684
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.0967439698935895 Z_err_max1: 4.338148782913693
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 6.03693818327957 Z_err_max1: 3.6837078665138865
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 7.217420316513481 Z_err_max1: 4.074395514032938
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.37626743367678 Z_err_max1: 4.125748075457644
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.631433950169061 Z_err_max1: 4.632619214695584
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 3.3803624236878536 Z_err_max1: 5.081161678283868
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 4.765599403038693 Z_err_max1: 5.476461041292469
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 7.674045078702193 Z_err_max1: 4.386459882120653
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.567588514492305 Z_err_max1: 6.75434479458419
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 4.846241657921713 Z_err_max1: 4.923266516873996
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 4.118155789942751 Z_err_max1: 6.232010724795398
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 5.263982081712633 Z_err_max1: 4.395301308014311
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.656072832314903 Z_err_max1: 3.6620690994521103
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.197435319626594 Z_err_max1: 3.6612797734822085
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.052920287539412 Z_err_max1: 4.542270580251811
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 3.9100482722151186 Z_err_max1: 5.035833803853295
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.693294295361127 Z_err_max1: 6.127394939139296
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.3197447679782215 Z_err_max1: 4.910952958562707
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.4770312113571356 Z_err_max1: 5.934978975114561
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 5.254626302003677 Z_err_max1: 4.913376487219233
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.8383729447254495 Z_err_max1: 4.659779113261087
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.593667342167367 Z_err_max1: 5.146466827287677
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3258) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3258) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.353633838589761 Z_err_max1: 4.758601592030546
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 4.61467012996454 Z_err_max1: 4.5906244875709055
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.743156979603354 Z_err_max1: 6.1883472087112095
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 7.389778178081277 Z_err_max1: 4.222602133374974
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.099154122150635 Z_err_max1: 4.672321346071312
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.090973689678335 Z_err_max1: 3.2536052960851842
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3202) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3202) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 3.9933630129782367 Z_err_max1: 5.1053153041470765
# (map_fun_fmle pid=3258) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3258) Z_err_max: 4.3842881346379095 Z_err_max1: 3.8637989284746896 [repeated 2x across cluster]
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 5.1636695597794855 Z_err_max1: 5.7752591308169
# (map_fun_fmle pid=3050) SARX is over [repeated 3x across cluster]
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3050) fmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.185362299853723 Z_err_max1: 2.4715502553293116
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 4.865002568105805 Z_err_max1: 5.092252481681151
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 7.0566624266248095 Z_err_max1: 4.972009142749451
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.716653382782686 Z_err_max1: 5.634850942649864
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.327010426079533 Z_err_max1: 4.418114918688826
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 3.579603519004385 Z_err_max1: 5.837500495526752
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.90277242745487 Z_err_max1: 4.4911675330057514
# (map_fun_fmle pid=3091) cmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) Z_err_max: 6.222047824024045 Z_err_max1: 5.5863643474787175 [repeated 2x across cluster]
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.334297785022396 Z_err_max1: 5.573619157394294
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3053) SARX is over
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.855631489987216 Z_err_max1: 5.225163393810454
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3091) fmle is over [repeated 4x across cluster]
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 5.647014126627033 Z_err_max1: 4.406691166621465
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.942563771751445 Z_err_max1: 4.086852799000785
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.40527455210173 Z_err_max1: 5.6807936715220215
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.576868375648752 Z_err_max1: 4.650405989887274
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.95856052628551 Z_err_max1: 5.945216797060832
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 4.286838065324501 Z_err_max1: 4.570599560707083
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.510180945170427 Z_err_max1: 4.9645638150700195
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 7.214104363179725 Z_err_max1: 4.581119507485285
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 5.854913908635669 Z_err_max1: 5.169245286200243
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3053) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 5.911473438152335 Z_err_max1: 5.86823563440405
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.65829591320821 Z_err_max1: 3.7508065763851985
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 4.932851375960886 Z_err_max1: 5.54333369289184
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 5.952576336643686 Z_err_max1: 3.701460180418618
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.608196855296111 Z_err_max1: 5.217219931994441
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 7.0934936884545365 Z_err_max1: 4.259966500146511
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 5.611135110743395 Z_err_max1: 5.431070535440818
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 5.67611279974873 Z_err_max1: 4.931541221541295
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 4.695567171781288 Z_err_max1: 4.216346056631509
# (map_fun_fmle pid=3055) cmle is over [repeated 3x across cluster]
# (map_fun_fmle pid=3055) Z_err_max: 6.638488830843032 Z_err_max1: 3.959163481315845 [repeated 3x across cluster]
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.565550532102099 Z_err_max1: 5.3451626357534066
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3052) SARX is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.642818721520694 Z_err_max1: 4.220193132783559
# (map_fun_fmle pid=3055) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 7.662096247816754 Z_err_max1: 4.147573994329701
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3052) fmle is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 6.20069292607808 Z_err_max1: 6.355716648169281
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3050) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.469072197941858 Z_err_max1: 4.293320910169223
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 6.188447350081183 Z_err_max1: 4.1851460865500165
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 6.096510955957404 Z_err_max1: 4.536140292243651
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.025574351119389 Z_err_max1: 5.692934472472911
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.53144266619747 Z_err_max1: 6.543865554958121
# (map_fun_fmle pid=3090) fmle is over
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3091) cmle is over
# (map_fun_fmle pid=3091) Z_err_max: 3.2220905148102927 Z_err_max1: 4.579845994993221
# (map_fun_fmle pid=3053) cmle is over
# (map_fun_fmle pid=3053) Z_err_max: 6.618264282123751 Z_err_max1: 4.6827902508551755
# (map_fun_fmle pid=3052) cmle is over
# (map_fun_fmle pid=3052) Z_err_max: 5.68933132907858 Z_err_max1: 3.47954439281682
# (map_fun_fmle pid=3091) SARX is over
# (map_fun_fmle pid=3052) SARX is over [repeated 2x across cluster]
# (map_fun_fmle pid=3050) cmle is over
# (map_fun_fmle pid=3050) Z_err_max: 7.083955503008003 Z_err_max1: 4.75521410054201
# (map_fun_fmle pid=3091) fmle is over
# (map_fun_fmle pid=3050) SARX is over
# (map_fun_fmle pid=3053) fmle is over
# (map_fun_fmle pid=3050) fmle is over [repeated 2x across cluster]
# (map_fun_fmle pid=3202) cmle is over
# (map_fun_fmle pid=3202) Z_err_max: 6.404961932282498 Z_err_max1: 4.134667727587859
# (map_fun_fmle pid=3202) SARX is over
# (map_fun_fmle pid=3202) fmle is over
# (map_fun_fmle pid=3290) cmle is over
# (map_fun_fmle pid=3290) Z_err_max: 6.067910728436452 Z_err_max1: 4.546832263400368
# (map_fun_fmle pid=3258) cmle is over
# (map_fun_fmle pid=3258) Z_err_max: 5.424938990331153 Z_err_max1: 3.4498584814218
# (map_fun_fmle pid=3290) SARX is over
# (map_fun_fmle pid=3258) SARX is over
# (map_fun_fmle pid=3343) cmle is over
# (map_fun_fmle pid=3343) Z_err_max: 5.349175596068617 Z_err_max1: 3.5708324326104166
# (map_fun_fmle pid=3290) fmle is over
# (map_fun_fmle pid=3258) fmle is over
# (map_fun_fmle pid=3343) SARX is over
# (map_fun_fmle pid=3343) fmle is over
# (map_fun_fmle pid=3055) cmle is over
# (map_fun_fmle pid=3055) Z_err_max: 6.306783346235097 Z_err_max1: 3.879787621341575
# (map_fun_fmle pid=3055) SARX is over
# (map_fun_fmle pid=3055) fmle is over
# (map_fun_fmle pid=3090) cmle is over
# (map_fun_fmle pid=3090) Z_err_max: 6.574097632374517 Z_err_max1: 5.2473994414145055
# (map_fun_fmle pid=3090) SARX is over
# (map_fun_fmle pid=3090) fmle is over
# 14139.547686338425

# %%
import ray
ray.shutdown()

# %%
# 结果汇总
BB = 500
q0 = 10
theta_hat_Block_n500_p50_B500 = np.zeros((BB,8,p))

ite_ini = np.zeros((BB,p))
ite_fZin = np.zeros((BB,p))
ite_fin = np.zeros((BB,p))
#tic1 = time()
for bt in range(BB):
    theta_hat_Block_n500_p50_B500[bt,:,:], ite_ini[bt,:], ite_fZin[bt,:], ite_fin[bt,:] = results500_p50whole[bt][0], results500_p50whole[bt][1],results500_p50whole[bt][2],results500_p50whole[bt][3]
#toc1 = time()

# %%
cc = list(set(range(BB)).difference(set(np.where(ite_fin==0)[0])))
ECP = np.zeros(len(cc))
i=0
for b in cc:
    ECP[i] = (theta_hat_Block_n500_p50_B500[b,6,jj]<=rho[jj]) & (rho[jj]<=theta_hat_Block_n500_p50_B500[b,7,jj])
    i = i+1

# %%
np.mean(ECP) #1000 p50 j=20, cp=0.96
# Out:
# 0.962

# %%
#cmle
np.nanmean(abs(theta_hat_Block_n500_p50_B500[cc,0,:]-((rho.reshape((p,1))@np.ones((1,BB))).T)[cc,:]))
# Out:
# 0.03516811415356755

# %%
#SARX
np.nanmean(abs(theta_hat_Block_n500_p50_B500[cc,1,:]-((rho.reshape((p,1))@np.ones((1,BB))).T)[cc,:]))
# Out:
# 0.010271353141702399

# %%
#fmle
np.nanmean(abs(theta_hat_Block_n500_p50_B500[cc,2,:]-((rho.reshape((p,1))@np.ones((1,BB))).T)[cc,:]))
# Out:
# 0.020997761507708546

# %%
#保存估计数据
for b in range(BB):
    pd.DataFrame(theta_hat_Block_n500_p50_B500[b,:,:]).to_csv("Results_Block_02/n500_p50_B500/theta_hat_Block_n500_p50_"+str(b)+'_.csv',index=False)
